# %%
! pip install pandas
! pip install matplotlib
! pip install seaborn
! pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\ead\pictures\projeto\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\ead\pictures\projeto\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\ead\pictures\projeto\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\ead\pictures\projeto\.venv\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ead\pictures\projeto\.venv\lib\site-packages (from scikit-learn) (3.5.0)

# %%
# Carregar pacotes necessários
import pandas as pd

# Carregar o dataset
file_path = 'dataset/expanded_diabetes_dataset.csv'  # Substitua pelo caminho correto do seu arquivo
diabetes_df = pd.read_csv(file_path)

# %%
# Exibir as primeiras linhas e informações básicas
print(diabetes_df.head())
# Out:
#                              Target Genetic Markers Autoantibodies  \
# 0          Steroid-Induced Diabetes        Positive       Negative
# 1  Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                       Prediabetic        Positive       Positive
# 3                   Type 1 Diabetes        Negative       Positive
# 4                  Wolfram Syndrome        Negative       Negative
#
#   Family History Environmental Factors  Insulin Levels        Age        BMI  \
# 0             No               Present       38.186845  44.514581  38.276831
# 1             No               Present       13.601378   0.959215  17.061191
# 2            Yes               Present       25.726708  35.056766  24.794768
# 3             No               Present        8.162440   6.998362  16.269794
# 4            Yes               Present       16.239333  10.180812  17.513180
#
#   Physical Activity Dietary Habits  ...  Pulmonary Function  \
# 0              High        Healthy  ...           73.595637
# 1              High        Healthy  ...           60.113721
# 2              High      Unhealthy  ...           83.175475
# 3               Low      Unhealthy  ...           89.277008
# 4              High        Healthy  ...           41.031812
#
#    Cystic Fibrosis Diagnosis  Steroid Use History  Genetic Testing  \
# 0                         No                   No         Positive
# 1                        Yes                   No         Negative
# 2                        Yes                   No         Negative
# 3                        Yes                   No         Positive
# 4                         No                   No         Positive
#
#   Neurological Assessments Liver Function Tests Digestive Enzyme Levels  \
# 0                 3.105559               Normal               57.352965
# 1                 0.982441               Normal               28.722989
# 2                 1.010715             Abnormal               54.070581
# 3                 1.963268             Abnormal               57.456534
# 4                 1.035984               Normal               24.318948
#
#         Urine Test Birth Weight Early Onset Symptoms
# 0  Ketones Present  2575.421825                   No
# 1  Glucose Present  1861.923305                  Yes
# 2  Ketones Present  3800.197491                  Yes
# 3  Ketones Present  3394.978089                   No
# 4  Protein Present  1765.715783                   No
#
# [5 rows x 34 columns]

# %%
print(diabetes_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Target                         140000 non-null  object
#  1   Genetic Markers                140000 non-null  object
#  2   Autoantibodies                 140000 non-null  object
#  3   Family History                 140000 non-null  object
#  4   Environmental Factors          140000 non-null  object
#  5   Insulin Levels                 140000 non-null  float64
#  6   Age                            140000 non-null  float64
#  7   BMI                            140000 non-null  float64
#  8   Physical Activity              140000 non-null  object
#  9   Dietary Habits                 140000 non-null  object
#  10  Blood Pressure                 140000 non-null  float64
#  11  Cholesterol Levels             140000 non-null  float64
#  12  Waist Circumference            140000 non-null  float64
#  13  Blood Glucose Levels           140000 non-null  float64
#  14  Ethnicity                      140000 non-null  object
#  15  Socioeconomic Factors          140000 non-null  object
#  16  Smoking Status                 140000 non-null  object
#  17  Alcohol Consumption            140000 non-null  object
#  18  Glucose Tolerance Test         140000 non-null  object
#  19  History of PCOS                140000 non-null  object
#  20  Previous Gestational Diabetes  140000 non-null  object
#  21  Pregnancy History              140000 non-null  object
#  22  Weight Gain During Pregnancy   140000 non-null  float64
#  23  Pancreatic Health              140000 non-null  float64
#  24  Pulmonary Function             140000 non-null  float64
#  25  Cystic Fibrosis Diagnosis      140000 non-null  object
#  26  Steroid Use History            140000 non-null  object
#  27  Genetic Testing                140000 non-null  object
#  28  Neurological Assessments       140000 non-null  float64
#  29  Liver Function Tests           140000 non-null  object
#  30  Digestive Enzyme Levels        140000 non-null  float64
#  31  Urine Test                     140000 non-null  object
#  32  Birth Weight                   140000 non-null  float64
#  33  Early Onset Symptoms           140000 non-null  object
# dtypes: float64(13), object(21)
# memory usage: 36.3+ MB
# None

# %%
print(diabetes_df.isnull().sum())
# Out:
# Target                           0
# Genetic Markers                  0
# Autoantibodies                   0
# Family History                   0
# Environmental Factors            0
# Insulin Levels                   0
# Age                              0
# BMI                              0
# Physical Activity                0
# Dietary Habits                   0
# Blood Pressure                   0
# Cholesterol Levels               0
# Waist Circumference              0
# Blood Glucose Levels             0
# Ethnicity                        0
# Socioeconomic Factors            0
# Smoking Status                   0
# Alcohol Consumption              0
# Glucose Tolerance Test           0
# History of PCOS                  0
# Previous Gestational Diabetes    0
# Pregnancy History                0
# Weight Gain During Pregnancy     0
# Pancreatic Health                0
# Pulmonary Function               0
# Cystic Fibrosis Diagnosis        0
# Steroid Use History              0
# Genetic Testing                  0
# Neurological Assessments         0
# Liver Function Tests             0
# Digestive Enzyme Levels          0
# Urine Test                       0
# Birth Weight                     0
# Early Onset Symptoms             0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configurações para visualização
sns.set(style="whitegrid")

# Distribuição da variável Target
plt.figure(figsize=(10, 6))
sns.countplot(data=diabetes_df, x="Target")
plt.title("Distribuição dos Tipos de Diabetes e Condições Associadas")
plt.xlabel("Tipos de Diabetes / Condições")
plt.ylabel("Contagem")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
# Distribuição de algumas variáveis numéricas
numeric_cols = ["Insulin Levels", "Age", "BMI", "Blood Pressure", "Cholesterol Levels", "Blood Glucose Levels"]
diabetes_df[numeric_cols].hist(bins=15, figsize=(15, 10), color='skyblue', edgecolor='black')
plt.suptitle("Distribuição de Variáveis Numéricas")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
# Separar os dados entre features (X) e target (y)
X = diabetes_df.drop(columns=["Target"])
y = diabetes_df["Target"]

# %%
# Identificar colunas numéricas e categóricas
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns
categorical_features = X.select_dtypes(include=["object"]).columns

# %%
# Configurar o pré-processador para normalizar e codificar variáveis
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(), categorical_features)
    ])

X_processed = preprocessor.fit_transform(X)

# %%
# Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape)
# Out:
# (112000, 58) (28000, 58)

# %% [markdown]
# ---
# # **Versão usando *RandomForest***

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
# Inicializar o modelo de classificação
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Avaliação inicial com validação cruzada
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="accuracy")
print("Acurácia média (Validação Cruzada):", cv_scores.mean())
# Out:
# Acurácia média (Validação Cruzada): 0.9103749999999999

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Previsões no conjunto de teste
y_pred = model.predict(X_test)

# %%
# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia no conjunto de teste: {accuracy:.2f}")
# Out:
# Acurácia no conjunto de teste: 0.92

# %%
# Relatório de classificação
print("Relatório de Classificação:")
print(classification_report(y_test, y_pred))
# Out:
# Relatório de Classificação:
#                                             precision    recall  f1-score   support
#
#    Cystic Fibrosis-Related Diabetes (CFRD)       0.98      0.90      0.94      2133
#                       Gestational Diabetes       0.91      0.90      0.90      2164
#                                       LADA       0.96      0.94      0.95      2162
#                                       MODY       0.91      0.92      0.92      2222
#           Neonatal Diabetes Mellitus (NDM)       1.00      1.00      1.00      2157
#                                Prediabetic       0.92      0.98      0.95      2169
#                         Secondary Diabetes       0.91      0.83      0.87      2212
#                   Steroid-Induced Diabetes       0.89      0.85      0.87      2108
#                            Type 1 Diabetes       0.92      0.97      0.94      2164
#                            Type 2 Diabetes       0.94      0.87      0.90      2139
# Type 3c Diabetes (Pancreatogenic Diabetes)       0.78      0.95      0.86      2082
#                  Wolcott-Rallison Syndrome       0.97      0.93      0.95      2184
#                           Wolfram Syndrome       0.93      0.97      0.95      2104
#
#                                   accuracy                           0.92     28000
#                                  macro avg       0.93      0.92      0.92     28000
#                               weighted avg       0.93      0.92      0.92     28000

# %%
# Matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Matriz de Confusão")
plt.xlabel("Predito")
plt.ylabel("Verdadeiro")
plt.show()

# %% [markdown]
# ---
# # **Versão usando *Naive Bayes***

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# %%
# Inicializar o modelo de classificação Naive Bayes
model = GaussianNB()
model.fit(X_train, y_train)  # Convertendo para array se X_train é uma matriz esparsa
# Out:
# GaussianNB()

# %%
# Avaliação inicial com validação cruzada
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="accuracy")
print("Acurácia média (Validação Cruzada):", cv_scores.mean())
# Out:
# Acurácia média (Validação Cruzada): 0.8126875

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Previsões no conjunto de teste
y_pred = model.predict(X_test)

# %%
# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia no conjunto de teste: {accuracy:.2f}")
# Out:
# Acurácia no conjunto de teste: 0.81

# %%
# Relatório de classificação
print("Relatório de Classificação:")
print(classification_report(y_test, y_pred))
# Out:
# Relatório de Classificação:
#                                             precision    recall  f1-score   support
#
#    Cystic Fibrosis-Related Diabetes (CFRD)       0.88      0.80      0.84      2133
#                       Gestational Diabetes       0.77      0.81      0.79      2164
#                                       LADA       0.88      0.85      0.87      2162
#                                       MODY       0.80      0.81      0.81      2222
#           Neonatal Diabetes Mellitus (NDM)       1.00      1.00      1.00      2157
#                                Prediabetic       0.88      0.90      0.89      2169
#                         Secondary Diabetes       0.69      0.61      0.65      2212
#                   Steroid-Induced Diabetes       0.67      0.67      0.67      2108
#                            Type 1 Diabetes       0.84      0.89      0.87      2164
#                            Type 2 Diabetes       0.72      0.75      0.74      2139
# Type 3c Diabetes (Pancreatogenic Diabetes)       0.68      0.74      0.71      2082
#                  Wolcott-Rallison Syndrome       0.88      0.88      0.88      2184
#                           Wolfram Syndrome       0.88      0.88      0.88      2104
#
#                                   accuracy                           0.81     28000
#                                  macro avg       0.81      0.81      0.81     28000
#                               weighted avg       0.81      0.81      0.81     28000

# %%
# Matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Matriz de Confusão")
plt.xlabel("Predito")
plt.ylabel("Verdadeiro")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # **Conclusão**
#
# ## O modelo de previsão de diabetes foi avaliado com base em métricas de desempenho e apresentou os resultados acima.
